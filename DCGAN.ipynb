# %% [markdown]
# # DCGAN 직접 만들어보기
#
# - 참고 링크 : https://dreamgonfly.github.io/blog/gan-explained/
#
# - 참고 깃허브 : https://github.com/dreamgonfly/GAN-tutorial/

# %%
### 라이브러리 및 데이터 불러오기
# 필요한 라이브러리를 불러온다.
import torch
import torch.nn as nn
from torch.optim import Adam
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
from torch.autograd import Variable
import pickle

# 데이터 전처리 방식을 지정한다.
transform = transforms.Compose([
        transforms.ToTensor(), # 데이터를 PyTorch의 Tensor 형식으로 바꾼다.
        transforms.Normalize(mean=(0.5,), std=(0.5,)) # 픽셀값 0 ~ 1 -> -1 ~ 1
])

# MNIST 데이터셋을 불러온다. 지정한 폴더에 없을 경우 자동으로 다운로드한다.
mnist = datasets.MNIST(root='data', download=True, transform=transform)

# 데이터를 한번에 batch_size만큼만 가져오는 dataloader를 만든다.
dataloader = DataLoader(mnist, batch_size=60, shuffle=True)

# %%
import os
import imageio

if torch.cuda.is_available():
    use_gpu = True
leave_log = True
if leave_log:
    result_dir = 'DCGAN_generated_images'
    if not os.path.isdir(result_dir):
        os.mkdir(result_dir)

# %%
# DCGAN의 생성자

class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        self.main = nn.Sequential(
            nn.ConvTranspose2d(in_channels=100, out_channels=28*8, kernel_size=7, stride=1, padding=0, bias=False),
            nn.BatchNorm2d(num_features=28*8),
            nn.ReLU(inplace=True),
            nn.ConvTranspose2d(in_channels=28*8, out_channels=28*4, kernel_size=4, stride=2, padding=1, bias=False),
            nn.BatchNorm2d(num_features=28*4),
            nn.ReLU(True),
            nn.ConvTranspose2d(in_channels=28*4, out_channels=1, kernel_size=4, stride=2, padding=1, bias=False),
            nn.Tanh())
        
    # (batch_size, 100)크기의 랜덤 벡터를 받아
    # 이미지를 (batch_size, 1, 28, 28)크기로 출력
    def forward(self, inputs):
        inputs = inputs.view(-1, 100, 1, 1)
        return self.main(inputs)

# %%
# DCGAN의 구분자

class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.main = nn.Sequential(
          nn.Conv2d(in_channels=1, out_channels=28*4, kernel_size=4, stride=2, padding=1, bias=False),
          nn.BatchNorm2d(num_features=28*4),
          nn.LeakyReLU(0.2, inplace=True),
          nn.Conv2d(in_channels=28*4, out_channels=28*8, kernel_size=4, stride=2, padding=1, bias=False),
          nn.BatchNorm2d(num_features=28*8),
          nn.LeakyReLU(0.2, inplace=True),
          nn.Conv2d(in_channels=28*8, out_channels=1, kernel_size=7, stride=1, padding=0, bias=False),
          nn.Sigmoid())
        
    # (batch_size x 1 x 28 x 28) 크기의 이미지를 받아
    # 이미지가 진짜일 확률을 0~1 사이로 출력한다.
    def forward(self, inputs):
        o = self.main(inputs)
        return o.view(-1, 1)

# %%
### 생성자와 구분자 객체 만들기
G = Generator()
D = Discriminator()

if use_gpu:
    G.cuda()
    D.cuda()

# %%
### 손실 함수와 최적화 기법 지정하기
# Binary Cross Entropy loss
criterion = nn.BCELoss()

# 생성자의 매개 변수를 최적화하는 Adam optimizer
G_optimizer = Adam(G.parameters(), lr=0.0002, betas=(0.5, 0.999))
# 구분자의 매개 변수를 최적화하는 Adam optimizer
D_optimizer = Adam(D.parameters(), lr=0.0002, betas=(0.5, 0.999))

# %%
# 학습 결과 시각화하기
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np

def square_plot(data, path):
    """Take an array of shape (n, height, width) or (n, height, width , 3)
       and visualize each (height, width) thing in a grid of size approx. sqrt(n) by sqrt(n)"""

    if type(data) == list:
	    data = np.concatenate(data)
    # normalize data for display
    data = (data - data.min()) / (data.max() - data.min())

    # force the number of filters to be square
    n = int(np.ceil(np.sqrt(data.shape[0])))

    padding = (((0, n ** 2 - data.shape[0]) ,
                (0, 1), (0, 1))  # add some space between filters
               + ((0, 0),) * (data.ndim - 3))  # don't pad the last dimension (if there is one)
    data = np.pad(data , padding, mode='constant' , constant_values=1)  # pad with ones (white)

    # tilethe filters into an image
    data = data.reshape((n , n) + data.shape[1:]).transpose((0 , 2 , 1 , 3) + tuple(range(4 , data.ndim + 1)))

    data = data.reshape((n * data.shape[1] , n * data.shape[3]) + data.shape[4:])

    plt.imsave(path, data, cmap='gray')

# %%
if leave_log:
    train_hist = {}
    train_hist['D_losses'] = []
    train_hist['G_losses'] = []
    generated_images = []
    
z_fixed = Variable(torch.randn(5 * 5, 100), volatile=True)
if use_gpu:
    z_fixed = z_fixed.cuda()
# Out:
# <ipython-input-10-8b401d4d980b>:7: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   z_fixed = Variable(torch.randn(5 * 5, 100), volatile=True)

# %%
### 모델 학습을 위한 반복문
# 데이터셋을 100번 돌며 학습한다.
for epoch in range(100):
    
    if leave_log:
        D_losses = []
        G_losses = []
    
    # 한번에 batch_size만큼 데이터를 가져온다.
    for real_data, _ in dataloader:
        batch_size = real_data.size(0)
        
        # 데이터를 pytorch의 변수로 변환한다.
        real_data = Variable(real_data)

        ### 구분자 학습시키기

        # 이미지가 진짜일 때 정답 값은 1이고 가짜일 때는 0이다.
        # 정답지에 해당하는 변수를 만든다.
        target_real = Variable(torch.ones(batch_size, 1))
        target_fake = Variable(torch.zeros(batch_size, 1))
         
        if use_gpu:
            real_data, target_real, target_fake = real_data.cuda(), target_real.cuda(), target_fake.cuda()
            
        # 진짜 이미지를 구분자에 넣는다.
        D_result_from_real = D(real_data)
        # 구분자의 출력값이 정답지인 1에서 멀수록 loss가 높아진다.
        D_loss_real = criterion(D_result_from_real, target_real)

        # 생성자에 입력으로 줄 랜덤 벡터 z를 만든다.
        z = Variable(torch.randn((batch_size, 100)))
        
        if use_gpu:
            z = z.cuda()
            
        # 생성자로 가짜 이미지를 생성한다.
        fake_data = G(z)
        
        # 생성자가 만든 가짜 이미지를 구분자에 넣는다.
        D_result_from_fake = D(fake_data)
        # 구분자의 출력값이 정답지인 0에서 멀수록 loss가 높아진다.
        D_loss_fake = criterion(D_result_from_fake, target_fake)
        
        # 구분자의 loss는 두 문제에서 계산된 loss의 합이다.
        D_loss = D_loss_real + D_loss_fake
        
        # 구분자의 매개 변수의 미분값을 0으로 초기화한다.
        D.zero_grad()
        # 역전파를 통해 매개 변수의 loss에 대한 미분값을 계산한다.
        D_loss.backward()
        # 최적화 기법을 이용해 구분자의 매개 변수를 업데이트한다.
        D_optimizer.step()
        
#         if leave_log:
#             D_losses.append(D_loss.data[0])
        if leave_log:
            D_losses.append(D_loss.data)

        # train generator G

        ### 생성자 학습시키기
        
        # 생성자에 입력으로 줄 랜덤 벡터 z를 만든다.
        z = Variable(torch.randn((batch_size, 100)))
        
        if use_gpu:
            z = z.cuda()
        
        # 생성자로 가짜 이미지를 생성한다.
        fake_data = G(z)
        # 생성자가 만든 가짜 이미지를 구분자에 넣는다.
        D_result_from_fake = D(fake_data)
        # 생성자의 입장에서 구분자의 출력값이 1에서 멀수록 loss가 높아진다.
        G_loss = criterion(D_result_from_fake, target_real)
        
        # 생성자의 매개 변수의 미분값을 0으로 초기화한다.
        G.zero_grad()
        # 역전파를 통해 매개 변수의 loss에 대한 미분값을 계산한다.
        G_loss.backward()
        # 최적화 기법을 이용해 생성자의 매개 변수를 업데이트한다.
        G_optimizer.step()
        
#         if leave_log:
#             G_losses.append(G_loss.data[0])
        if leave_log:
            G_losses.append(G_loss.data)
            
    if leave_log:
        true_positive_rate = (D_result_from_real > 0.5).float().mean().data
        true_negative_rate = (D_result_from_fake < 0.5).float().mean().data
        base_message = ("Epoch: {epoch:<3d} D Loss: {d_loss:<8.6} G Loss: {g_loss:<8.6} "
                        "True Positive Rate: {tpr:<5.1%} True Negative Rate: {tnr:<5.1%}"
                       )
        message = base_message.format(
                    epoch=epoch,
                    d_loss=sum(D_losses)/len(D_losses),
                    g_loss=sum(G_losses)/len(G_losses),
                    tpr=true_positive_rate,
                    tnr=true_negative_rate
        )
        print(message)
    
    if leave_log:
        fake_data_fixed = G(z_fixed)
        image_path = result_dir + '/epoch{}.png'.format(epoch)
        square_plot(fake_data_fixed.view(25, 28, 28).cpu().data.numpy(), path=image_path)
        generated_images.append(image_path)
    
    if leave_log:
        train_hist['D_losses'].append(torch.mean(torch.FloatTensor(D_losses)))
        train_hist['G_losses'].append(torch.mean(torch.FloatTensor(G_losses)))

torch.save(G.state_dict(), "dcgan_generator.pkl")
torch.save(D.state_dict(), "dcgan_discriminator.pkl")
with open('dcgan_train_history.pkl', 'wb') as f:
    pickle.dump(train_hist, f)

generated_image_array = [imageio.imread(generated_image) for generated_image in generated_images]
imageio.mimsave(result_dir + '/DCGAN_generation.gif', generated_image_array, fps=5)
# Out:
# Epoch: 0   D Loss: 0.60224  G Loss: 1.85554  True Positive Rate: 100.0% True Negative Rate: 100.0%
# Epoch: 1   D Loss: 0.495349 G Loss: 2.17141  True Positive Rate: 95.0% True Negative Rate: 93.3%
# Epoch: 2   D Loss: 0.5185   G Loss: 2.20408  True Positive Rate: 100.0% True Negative Rate: 95.0%
# Epoch: 3   D Loss: 0.522552 G Loss: 2.21224  True Positive Rate: 86.7% True Negative Rate: 86.7%
# Epoch: 4   D Loss: 0.534687 G Loss: 2.23846  True Positive Rate: 91.7% True Negative Rate: 98.3%
# Epoch: 5   D Loss: 0.516657 G Loss: 2.28838  True Positive Rate: 86.7% True Negative Rate: 86.7%
# Epoch: 6   D Loss: 0.530416 G Loss: 2.32403  True Positive Rate: 86.7% True Negative Rate: 98.3%
# Epoch: 7   D Loss: 0.487988 G Loss: 2.4103   True Positive Rate: 96.7% True Negative Rate: 96.7%
# Epoch: 8   D Loss: 0.492982 G Loss: 2.46834  True Positive Rate: 96.7% True Negative Rate: 98.3%
# Epoch: 9   D Loss: 0.47654  G Loss: 2.53089  True Positive Rate: 85.0% True Negative Rate: 98.3%
# Epoch: 10  D Loss: 0.491591 G Loss: 2.52114  True Positive Rate: 50.0% True Negative Rate: 75.0%
# Epoch: 11  D Loss: 0.450745 G Loss: 2.61097  True Positive Rate: 65.0% True Negative Rate: 26.7%
# Epoch: 12  D Loss: 0.457334 G Loss: 2.65453  True Positive Rate: 95.0% True Negative Rate: 100.0%
# Epoch: 13  D Loss: 0.44426  G Loss: 2.70792  True Positive Rate: 95.0% True Negative Rate: 96.7%
# Epoch: 14  D Loss: 0.444918 G Loss: 2.70183  True Positive Rate: 100.0% True Negative Rate: 88.3%
# Epoch: 15  D Loss: 0.431951 G Loss: 2.77701  True Positive Rate: 65.0% True Negative Rate: 75.0%
# Epoch: 16  D Loss: 0.41191  G Loss: 2.84878  True Positive Rate: 98.3% True Negative Rate: 88.3%
# Epoch: 17  D Loss: 0.417457 G Loss: 2.86852  True Positive Rate: 80.0% True Negative Rate: 93.3%
# Epoch: 18  D Loss: 0.414959 G Loss: 2.91158  True Positive Rate: 98.3% True Negative Rate: 98.3%
# Epoch: 19  D Loss: 0.393491 G Loss: 2.91451  True Positive Rate: 95.0% True Negative Rate: 100.0%
# Epoch: 20  D Loss: 0.401301 G Loss: 2.96987  True Positive Rate: 100.0% True Negative Rate: 100.0%
# Epoch: 21  D Loss: 0.39001  G Loss: 3.0069   True Positive Rate: 100.0% True Negative Rate: 100.0%
# Epoch: 22  D Loss: 0.381469 G Loss: 3.02921  True Positive Rate: 66.7% True Negative Rate: 85.0%
# Epoch: 23  D Loss: 0.383019 G Loss: 3.08251  True Positive Rate: 100.0% True Negative Rate: 100.0%
# Epoch: 24  D Loss: 0.374384 G Loss: 3.10051  True Positive Rate: 100.0% True Negative Rate: 100.0%
# Epoch: 25  D Loss: 0.37858  G Loss: 3.11388  True Positive Rate: 100.0% True Negative Rate: 93.3%
# Epoch: 26  D Loss: 0.371625 G Loss: 3.14533  True Positive Rate: 80.0% True Negative Rate: 53.3%
# Epoch: 27  D Loss: 0.36423  G Loss: 3.17522  True Positive Rate: 81.7% True Negative Rate: 75.0%
# Epoch: 28  D Loss: 0.350314 G Loss: 3.20533  True Positive Rate: 100.0% True Negative Rate: 100.0%
# Epoch: 29  D Loss: 0.3685   G Loss: 3.20889  True Positive Rate: 93.3% True Negative Rate: 98.3%
# Epoch: 30  D Loss: 0.345814 G Loss: 3.25138  True Positive Rate: 96.7% True Negative Rate: 93.3%
# Epoch: 31  D Loss: 0.359581 G Loss: 3.25774  True Positive Rate: 100.0% True Negative Rate: 91.7%
# Epoch: 32  D Loss: 0.345512 G Loss: 3.30188  True Positive Rate: 95.0% True Negative Rate: 96.7%
# Epoch: 33  D Loss: 0.355839 G Loss: 3.32018  True Positive Rate: 100.0% True Negative Rate: 98.3%
# Epoch: 34  D Loss: 0.342517 G Loss: 3.329    True Positive Rate: 91.7% True Negative Rate: 100.0%
# Epoch: 35  D Loss: 0.334296 G Loss: 3.29935  True Positive Rate: 100.0% True Negative Rate: 100.0%
# Epoch: 36  D Loss: 0.352573 G Loss: 3.3251   True Positive Rate: 100.0% True Negative Rate: 100.0%
# Epoch: 37  D Loss: 0.346284 G Loss: 3.34736  True Positive Rate: 100.0% True Negative Rate: 100.0%
# Epoch: 38  D Loss: 0.333408 G Loss: 3.3964   True Positive Rate: 96.7% True Negative Rate: 86.7%
# Epoch: 39  D Loss: 0.333193 G Loss: 3.41396  True Positive Rate: 95.0% True Negative Rate: 100.0%
# Epoch: 40  D Loss: 0.330316 G Loss: 3.41665  True Positive Rate: 100.0% True Negative Rate: 96.7%
# Epoch: 41  D Loss: 0.336084 G Loss: 3.43814  True Positive Rate: 100.0% True Negative Rate: 98.3%
# Epoch: 42  D Loss: 0.310203 G Loss: 3.46833  True Positive Rate: 88.3% True Negative Rate: 93.3%
# Epoch: 43  D Loss: 0.32844  G Loss: 3.46271  True Positive Rate: 98.3% True Negative Rate: 93.3%
# Epoch: 44  D Loss: 0.323026 G Loss: 3.52503  True Positive Rate: 95.0% True Negative Rate: 91.7%
# Epoch: 45  D Loss: 0.326752 G Loss: 3.45673  True Positive Rate: 98.3% True Negative Rate: 100.0%
# Epoch: 46  D Loss: 0.317736 G Loss: 3.5301   True Positive Rate: 100.0% True Negative Rate: 100.0%
# Epoch: 47  D Loss: 0.318474 G Loss: 3.51066  True Positive Rate: 100.0% True Negative Rate: 98.3%
# Epoch: 48  D Loss: 0.318319 G Loss: 3.57945  True Positive Rate: 96.7% True Negative Rate: 100.0%
# Epoch: 49  D Loss: 0.329896 G Loss: 3.60398  True Positive Rate: 91.7% True Negative Rate: 100.0%
# Epoch: 50  D Loss: 0.287177 G Loss: 3.59469  True Positive Rate: 93.3% True Negative Rate: 98.3%
# Epoch: 51  D Loss: 0.30725  G Loss: 3.62258  True Positive Rate: 95.0% True Negative Rate: 95.0%
# Epoch: 52  D Loss: 0.310384 G Loss: 3.63842  True Positive Rate: 100.0% True Negative Rate: 100.0%
# Epoch: 53  D Loss: 0.303554 G Loss: 3.66919  True Positive Rate: 100.0% True Negative Rate: 100.0%
# Epoch: 54  D Loss: 0.30333  G Loss: 3.63688  True Positive Rate: 100.0% True Negative Rate: 100.0%
# Epoch: 55  D Loss: 0.29916  G Loss: 3.67344  True Positive Rate: 95.0% True Negative Rate: 96.7%
# Epoch: 56  D Loss: 0.318083 G Loss: 3.64524  True Positive Rate: 96.7% True Negative Rate: 61.7%
# Epoch: 57  D Loss: 0.28539  G Loss: 3.70385  True Positive Rate: 90.0% True Negative Rate: 85.0%
# Epoch: 58  D Loss: 0.283856 G Loss: 3.73299  True Positive Rate: 83.3% True Negative Rate: 96.7%
# Epoch: 59  D Loss: 0.301553 G Loss: 3.72151  True Positive Rate: 93.3% True Negative Rate: 100.0%
# Epoch: 60  D Loss: 0.299818 G Loss: 3.75358  True Positive Rate: 100.0% True Negative Rate: 88.3%
# Epoch: 61  D Loss: 0.279867 G Loss: 3.78121  True Positive Rate: 100.0% True Negative Rate: 100.0%
# Epoch: 62  D Loss: 0.291427 G Loss: 3.75052  True Positive Rate: 95.0% True Negative Rate: 100.0%
# Epoch: 63  D Loss: 0.27894  G Loss: 3.80013  True Positive Rate: 98.3% True Negative Rate: 100.0%
# Epoch: 64  D Loss: 0.297687 G Loss: 3.7563   True Positive Rate: 100.0% True Negative Rate: 100.0%
# Epoch: 65  D Loss: 0.278214 G Loss: 3.78934  True Positive Rate: 100.0% True Negative Rate: 98.3%
# Epoch: 66  D Loss: 0.28217  G Loss: 3.79151  True Positive Rate: 91.7% True Negative Rate: 88.3%
# Epoch: 67  D Loss: 0.269795 G Loss: 3.80758  True Positive Rate: 96.7% True Negative Rate: 100.0%
# Epoch: 68  D Loss: 0.287476 G Loss: 3.8405   True Positive Rate: 100.0% True Negative Rate: 90.0%
# Epoch: 69  D Loss: 0.2779   G Loss: 3.88077  True Positive Rate: 100.0% True Negative Rate: 98.3%
# Epoch: 70  D Loss: 0.286986 G Loss: 3.84282  True Positive Rate: 100.0% True Negative Rate: 100.0%
# Epoch: 71  D Loss: 0.268125 G Loss: 3.85402  True Positive Rate: 95.0% True Negative Rate: 90.0%
# Epoch: 72  D Loss: 0.269522 G Loss: 3.90085  True Positive Rate: 78.3% True Negative Rate: 86.7%
# Epoch: 73  D Loss: 0.302138 G Loss: 3.87821  True Positive Rate: 100.0% True Negative Rate: 98.3%
# Epoch: 74  D Loss: 0.265939 G Loss: 3.90784  True Positive Rate: 93.3% True Negative Rate: 93.3%
# Epoch: 75  D Loss: 0.256828 G Loss: 3.94907  True Positive Rate: 100.0% True Negative Rate: 98.3%
# Epoch: 76  D Loss: 0.257546 G Loss: 3.95782  True Positive Rate: 95.0% True Negative Rate: 93.3%
# Epoch: 77  D Loss: 0.265281 G Loss: 3.94927  True Positive Rate: 100.0% True Negative Rate: 100.0%
# Epoch: 78  D Loss: 0.263348 G Loss: 3.9831   True Positive Rate: 100.0% True Negative Rate: 100.0%
# Epoch: 79  D Loss: 0.269662 G Loss: 4.02031  True Positive Rate: 98.3% True Negative Rate: 88.3%
# Epoch: 80  D Loss: 0.250936 G Loss: 4.00534  True Positive Rate: 100.0% True Negative Rate: 95.0%
# Epoch: 81  D Loss: 0.26436  G Loss: 4.01662  True Positive Rate: 100.0% True Negative Rate: 100.0%
# Epoch: 82  D Loss: 0.243662 G Loss: 4.08239  True Positive Rate: 95.0% True Negative Rate: 95.0%
# Epoch: 83  D Loss: 0.281638 G Loss: 4.04522  True Positive Rate: 96.7% True Negative Rate: 93.3%
# Epoch: 84  D Loss: 0.256735 G Loss: 4.07475  True Positive Rate: 100.0% True Negative Rate: 98.3%
# Epoch: 85  D Loss: 0.255928 G Loss: 4.03851  True Positive Rate: 96.7% True Negative Rate: 98.3%
# Epoch: 86  D Loss: 0.237623 G Loss: 4.13371  True Positive Rate: 100.0% True Negative Rate: 98.3%
# Epoch: 87  D Loss: 0.276064 G Loss: 4.03771  True Positive Rate: 98.3% True Negative Rate: 100.0%
# Epoch: 88  D Loss: 0.248995 G Loss: 4.04382  True Positive Rate: 100.0% True Negative Rate: 100.0%
# Epoch: 89  D Loss: 0.250392 G Loss: 4.05819  True Positive Rate: 98.3% True Negative Rate: 98.3%
# Epoch: 90  D Loss: 0.285996 G Loss: 4.06951  True Positive Rate: 71.7% True Negative Rate: 78.3%
# Epoch: 91  D Loss: 0.242562 G Loss: 4.09907  True Positive Rate: 100.0% True Negative Rate: 98.3%
# Epoch: 92  D Loss: 0.252146 G Loss: 4.09294  True Positive Rate: 100.0% True Negative Rate: 98.3%
# Epoch: 93  D Loss: 0.220803 G Loss: 4.17141  True Positive Rate: 100.0% True Negative Rate: 96.7%
# Epoch: 94  D Loss: 0.248277 G Loss: 4.14344  True Positive Rate: 100.0% True Negative Rate: 100.0%
# Epoch: 95  D Loss: 0.243487 G Loss: 4.21625  True Positive Rate: 100.0% True Negative Rate: 98.3%
# Epoch: 96  D Loss: 0.250864 G Loss: 4.1151   True Positive Rate: 100.0% True Negative Rate: 93.3%
# Epoch: 97  D Loss: 0.25166  G Loss: 4.16762  True Positive Rate: 100.0% True Negative Rate: 98.3%
# Epoch: 98  D Loss: 0.240984 G Loss: 4.17138  True Positive Rate: 100.0% True Negative Rate: 95.0%
# Epoch: 99  D Loss: 0.239019 G Loss: 4.19674  True Positive Rate: 65.0% True Negative Rate: 78.3%
